# %%
import pandas as pd
import numpy as np
import string
import re
import nltk
import json
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords  
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder, label_binarize
from sklearn.linear_model import SGDClassifier
from collections import Counter
import nlpaug.augmenter.word as naw
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score

# %% [markdown]
# ## Data Loading & Preprocessing

# %%
faq_file = open("./chatbot.txt").read()
data = json.loads(faq_file)
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#                                             question  \
# 0                     Where can I enrol for Aadhaar?
# 1  What are the documents required for enrolment ...
# 2  Do I need to bring original documents for Aadh...
# 3    Do I have to pay any fee for Aadhaar enrolment?
# 4  What kind of data gets captured during Aadhaar...
#
#                                               answer  found_duplicate
# 0  You have to visit an Aadhaar Enrolment centre ...            False
# 1  You need to fill up an application form availa...            False
# 2  Yes, you need to bring original copies of supp...            False
# 3  No, Aadhaar enrolment is totally free of cost ...            False
# 4  There are two types of data gets captured for ...            False

# %%
df.drop(["found_duplicate"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# question    0
# answer      0
# dtype: int64

# %%
df.head()
# Out:
#                                             question  \
# 0                     Where can I enrol for Aadhaar?
# 1  What are the documents required for enrolment ...
# 2  Do I need to bring original documents for Aadh...
# 3    Do I have to pay any fee for Aadhaar enrolment?
# 4  What kind of data gets captured during Aadhaar...
#
#                                               answer
# 0  You have to visit an Aadhaar Enrolment centre ...
# 1  You need to fill up an application form availa...
# 2  Yes, you need to bring original copies of supp...
# 3  No, Aadhaar enrolment is totally free of cost ...
# 4  There are two types of data gets captured for ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words=stopwords.words('english')

# %%
lemmatizer = WordNetLemmatizer()

# %%
def clean_data(text):
    text=text.lower() #lower the text
    text = re.sub(r'[^\w\s]', '', text) #remove irrelevant characters    
    text = text.split() #convert sentence to tokens
    text = [lemmatizer.lemmatize(word) for word in text] #lemmatization
    text = " ".join(text) #converting tokens to sentence
    return text

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nlpaug.augmenter.word as naw

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sovan\\Downloads\\faq-chatbot-main'

# %%
# model_type: word2vec, glove or fasttext
aug = naw.SynonymAug(aug_src='wordnet')

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
aug_data = {}
for ques,ans in tqdm(zip(df['question'],df['answer'])):
    for i in range(4):
        aug_data.update({aug.augment(ques):ans})
# Out:
# 0it [00:00, ?it/s][nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sovan\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nlpaug\model\word_dict\wordnet.py:58, in WordNet.pos_tag(cls, tokens)
#      57 try:
# ---> 58     results = nltk.pos_tag(tokens)
#      59 except LookupError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     144 """
#     145 Use NLTK's currently recommended part of speech tagger to
#     146 tag the given list of tokens.
#    (...)    166 :rtype: list(tuple(str, str))
#     167 """
# --> 168 tagger = _get_tagger(lang)
#     169 return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\perceptron.py:180, in PerceptronTagger.__init__(self, load, lang, loc)
#     179 if load:
# --> 180     self.load_from_json(lang, loc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\perceptron.py:277, in PerceptronTagger.load_from_json(self, lang, loc)
#     276 if not loc:
# --> 277     loc = find(f"taggers/averaged_perceptron_tagger_{lang}")
#     279 def load_param(json_file):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng
#
#   Searched in:
#     - 'C:\\Users\\sovan/nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Local\\Programs\\Python\\Python313\\nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Local\\Programs\\Python\\Python313\\share\\nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Local\\Programs\\Python\\Python313\\lib\\nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[17], line 4
#       2 for ques,ans in tqdm(zip(df['question'],df['answer'])):
#       3     for i in range(4):
# ----> 4         aug_data.update({aug.augment(ques):ans})
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nlpaug\base_augmenter.py:119, in Augmenter.augment(self, data, n, num_thread)
#     115 # Single input with/without multiple input
#     116 else:
#     117     # Single Thread
#     118     if num_thread == 1:
# --> 119         augmented_results = [action_fx(clean_data) for _ in range(n)]
#     121     # Multi Thread
#     122     else:
#     123         augmented_results = self._parallel_augment(action_fx, clean_data, n=n, num_thread=num_thread)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nlpaug\augmenter\word\synonym.py:121, in SynonymAug.substitute(self, data)
#     117 doc = Doc(data, self.tokenizer(data))
#     119 original_tokens = doc.get_original_tokens()
# --> 121 pos = self.model.pos_tag(original_tokens)
#     123 aug_idxes = self._get_aug_idxes(pos)
#     124 if aug_idxes is None or len(aug_idxes) == 0:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nlpaug\model\word_dict\wordnet.py:61, in WordNet.pos_tag(cls, tokens)
#      59 except LookupError:
#      60     nltk.download('averaged_perceptron_tagger')
# ---> 61     results = nltk.pos_tag(tokens)
#      63 return results
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\__init__.py:168, in pos_tag(tokens, tagset, lang)
#     143 def pos_tag(tokens, tagset=None, lang="eng"):
#     144     """
#     145     Use NLTK's currently recommended part of speech tagger to
#     146     tag the given list of tokens.
#    (...)    166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\__init__.py:110, in _get_tagger(lang)
#     108     tagger = PerceptronTagger(lang=lang)
#     109 else:
# --> 110     tagger = PerceptronTagger()
#     111 return tagger
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\perceptron.py:180, in PerceptronTagger.__init__(self, load, lang, loc)
#     176 self.save_dir = path_join(
#     177     self.TRAINED_TAGGER_PATH, f"{self.TAGGER_NAME}_{self.lang}"
#     178 )
#     179 if load:
# --> 180     self.load_from_json(lang, loc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\tag\perceptron.py:277, in PerceptronTagger.load_from_json(self, lang, loc)
#     274 def load_from_json(self, lang="eng", loc=None):
#     275     # Automatically find path to the tagger if location is not specified.
#     276     if not loc:
# --> 277         loc = find(f"taggers/averaged_perceptron_tagger_{lang}")
#     279     def load_param(json_file):
#     280         with open(path_join(loc, json_file)) as fin:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng
#
#   Searched in:
#     - 'C:\\Users\\sovan/nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Local\\Programs\\Python\\Python313\\nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Local\\Programs\\Python\\Python313\\share\\nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Local\\Programs\\Python\\Python313\\lib\\nltk_data'
#     - 'C:\\Users\\sovan\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
aug_df = pd.DataFrame(aug_data.items(),columns=['question','answer'])
aug_df.head()
# Out:
# Empty DataFrame
# Columns: [question, answer]
# Index: []

# %%
final_df = pd.concat([df,aug_df])

# %%
final_df.to_csv("augmented.csv",index=False)

# %% [markdown]
# ## Modelling

# %%
final_df = pd.read_csv("augmented.csv")

# %%
X = final_df['question']
y = final_df['answer']

# %%
le = LabelEncoder()

# %%
y = le.fit_transform(y)

# %%
import pandas as pd
pd.Series(y).value_counts()
# Out:
# 6     2
# 20    1
# 21    1
# 15    1
# 3     1
# 9     1
# 19    1
# 1     1
# 14    1
# 4     1
# 5     1
# 2     1
# 12    1
# 13    1
# 10    1
# 8     1
# 0     1
# 11    1
# 7     1
# 17    1
# 16    1
# 18    1
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=100, test_size=0.2
)

# %%
tf = TfidfVectorizer(
    ngram_range=(1, 3),
    min_df=1,
    stop_words='english'
)

# %%
tf = TfidfVectorizer(
    ngram_range=(1,3),
    min_df=1,
    stop_words='english'
)

X_train_tf = tf.fit_transform(X_train)
X_test_tf = tf.transform(X_test)

# %%
model = SGDClassifier(n_jobs=-1,random_state=100,loss='modified_huber',alpha=0.0005)
model.fit(X_train_tf,y_train)
# Out:
# SGDClassifier(alpha=0.0005, loss='modified_huber', n_jobs=-1, random_state=100)

# %%
y_pred = model.predict(X_test_tf)

# %%
labels = np.unique(y_test)
ytest_prob = label_binarize(y_test, classes=labels)
ypred_prob = label_binarize(y_pred, classes=labels)

# %%
print("Accuracy Score:",accuracy_score(y_test,y_pred))
print("Precision Score:",precision_score(y_test,y_pred,average='micro'))
print("Recall Score:",recall_score(y_test,y_pred,average='micro'))
print("ROC-AUC Score:",roc_auc_score(ytest_prob,ypred_prob,multi_class='ovo',average='micro'))
# Out:
# Accuracy Score: 0.0
# Precision Score: 0.0
# Recall Score: 0.0
# ROC-AUC Score: 0.5

# %% [markdown]
# ## Testing

# %%
idx = 2 
print("Question:", X_test.iloc[idx])
print("Predicted Answer:", le.inverse_transform([model.predict(X_test_tf[idx])[0]])[0])
print("Actual Answer:", le.inverse_transform([y_test[idx]])[0])
# Out:
# Question: Is there any age limit for Aadhaar enrolment?
# Predicted Answer: No, Aadhaar enrolment is totally free of cost therefore you need not pay anything at the enrolment centre.
# Actual Answer: No, there is no age limit defined for Aadhaar Enrolment. Even a new born baby can also get Enroled for Aadhaar.

# %%
questn = "how to open new savings account"
clean_ques = clean_data(questn)
clean_ques = tf.transform([clean_ques])
print(f"Question: {questn}")
if np.amax(model.predict_proba(clean_ques))>0.1:
    print(f"\nPredicted Answer:\n{le.inverse_transform(model.predict(clean_ques))[0]}")
else:
    print(f"\nPredicted Answer:\n(Not sure about your question, This might help you):\n\n{le.inverse_transform(model.predict(clean_ques))[0]}")
# Out:
# Question: how to open new savings account
#
# Predicted Answer:
# (Not sure about your question, This might help you):
#
# Yes. The resident may be allowed to add minor fields such as House No., Lane No., Street Name, correcting typographic errors, minor changes/ corrections to pin code etc. to the address listed in the PoA document as long as these additions/modifications do not alter the base address mentioned in the PoA document. If the changes requested are substantial and change the base address that is listed in the PoA, the resident will require to provide an alternate PoA or enrol through an Introducer.

# %%
test_questions = [
    "how to open new savings account",
    "how to update address in aadhaar",
    "what is minimum age for aadhaar",
    "how to link aadhaar with bank",
    "how to download aadhaar card"
]

for question in test_questions:
    clean_q = clean_data(question)
    vec_q = tf.transform([clean_q])
    
    prediction = model.predict(vec_q)
    confidence = np.max(model.predict_proba(vec_q))
    
    print("Question:", question)
    print("Confidence:", round(confidence, 3))
    print("Predicted Answer:", le.inverse_transform(prediction)[0])
    print("-" * 80)
# Out:
# Question: how to open new savings account
# Confidence: 0.09
# Predicted Answer: Yes. The resident may be allowed to add minor fields such as House No., Lane No., Street Name, correcting typographic errors, minor changes/ corrections to pin code etc. to the address listed in the PoA document as long as these additions/modifications do not alter the base address mentioned in the PoA document. If the changes requested are substantial and change the base address that is listed in the PoA, the resident will require to provide an alternate PoA or enrol through an Introducer.
# --------------------------------------------------------------------------------
# Question: how to update address in aadhaar
# Confidence: 1.0
# Predicted Answer: Yes. The resident may be allowed to add minor fields such as House No., Lane No., Street Name, correcting typographic errors, minor changes/ corrections to pin code etc. to the address listed in the PoA document as long as these additions/modifications do not alter the base address mentioned in the PoA document. If the changes requested are substantial and change the base address that is listed in the PoA, the resident will require to provide an alternate PoA or enrol through an Introducer.
# --------------------------------------------------------------------------------
# Question: what is minimum age for aadhaar
# Confidence: 1.0
# Predicted Answer: You have to visit an Aadhaar Enrolment centre set up by Enrolment Agency to enrol for Aadhaar. You can also search nearest Enrolment centre by clicking on Locate Enrolment Center or https://appointments.uidai.gov.in/easearch.aspx . You have to enter State, District and locality for finding the nearest enrolment centre.
# --------------------------------------------------------------------------------
# Question: how to link aadhaar with bank
# Confidence: 1.0
# Predicted Answer: You have to visit an Aadhaar Enrolment centre set up by Enrolment Agency to enrol for Aadhaar. You can also search nearest Enrolment centre by clicking on Locate Enrolment Center or https://appointments.uidai.gov.in/easearch.aspx . You have to enter State, District and locality for finding the nearest enrolment centre.
# --------------------------------------------------------------------------------
# Question: how to download aadhaar card
# Confidence: 1.0
# Predicted Answer: You have to visit an Aadhaar Enrolment centre set up by Enrolment Agency to enrol for Aadhaar. You can also search nearest Enrolment centre by clicking on Locate Enrolment Center or https://appointments.uidai.gov.in/easearch.aspx . You have to enter State, District and locality for finding the nearest enrolment centre.
# --------------------------------------------------------------------------------
